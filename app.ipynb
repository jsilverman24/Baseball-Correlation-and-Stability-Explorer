# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import streamlit as st

# %%
df_26 = pd.read_csv("~/Desktop/stats.csv")
df_25 = pd.read_csv("~/Desktop/stats-2.csv")
df_24 = pd.read_csv("~/Desktop/stats-3.csv")

# %%
twofive_twofour = pd.merge(df_24,df_25,on = "player_id", how = "inner",suffixes=('_24', '_25'))

# %%
twofive_twofour.describe()
# Out:
#            player_id  year_24  player_age_24       ab_24       pa_24  \
# count      88.000000     88.0      88.000000   88.000000   88.000000
# mean   641757.363636   2024.0      27.784091  558.670455  627.068182
# std     51608.575121      0.0       3.668596   49.941281   56.513409
# min    457705.000000   2024.0      20.000000  440.000000  511.000000
# 25%    617782.500000   2024.0      25.000000  524.500000  590.250000
# 50%    664392.000000   2024.0      27.000000  563.000000  635.000000
# 75%    677683.250000   2024.0      31.000000  590.750000  666.750000
# max    694671.000000   2024.0      37.000000  671.000000  735.000000
#
#            hit_24   single_24  double_24  triple_24  home_run_24  ...  \
# count   88.000000   88.000000  88.000000  88.000000    88.000000  ...
# mean   147.306818   92.954545  28.761364   2.750000    22.840909  ...
# std     21.323107   16.898554   6.869881   2.841604     9.676237  ...
# min    104.000000   59.000000  16.000000   0.000000     2.000000  ...
# 25%    133.000000   81.000000  24.000000   1.000000    16.000000  ...
# 50%    144.000000   91.000000  28.000000   2.000000    21.000000  ...
# 75%    159.250000  103.250000  33.000000   4.000000    28.250000  ...
# max    211.000000  161.000000  48.000000  14.000000    58.000000  ...
#
#        linedrives_percent_25  linedrives_25  popups_percent_25  popups_25  \
# count              88.000000      88.000000          88.000000  88.000000
# mean               23.945455     103.136364           6.820455  29.181818
# std                 2.206464      19.992057           2.510216  11.066721
# min                17.900000      57.000000           1.000000   4.000000
# 25%                22.400000      90.000000           5.075000  21.750000
# 50%                24.100000     101.000000           6.800000  29.500000
# 75%                25.500000     112.500000           8.500000  36.000000
# max                29.000000     173.000000          13.400000  59.000000
#
#        maxeff_arm_2b_3b_sba_25  n_outs_above_average_25  \
# count                 5.000000                34.000000
# mean                 83.680000                 0.000000
# std                   3.306358                 6.888726
# min                  78.600000               -12.000000
# 25%                  83.100000                -3.750000
# 50%                  83.500000                -1.000000
# 75%                  86.100000                 3.750000
# max                  87.100000                21.000000
#
#        rel_league_reaction_distance_25  rel_league_burst_distance_25  \
# count                        32.000000                     32.000000
# mean                         -0.128125                     -0.412500
# std                           1.027441                      1.298324
# min                          -2.200000                     -3.000000
# 25%                          -0.725000                     -1.250000
# 50%                          -0.150000                     -0.400000
# 75%                           0.250000                      0.525000
# max                           3.400000                      2.700000
#
#        rel_league_routing_distance_25  sprint_speed_25
# count                       32.000000        88.000000
# mean                         0.034375        27.410227
# std                          0.556260         1.346348
# min                         -1.300000        24.400000
# 25%                         -0.400000        26.475000
# 50%                          0.100000        27.450000
# 75%                          0.400000        28.400000
# max                          1.100000        30.300000
#
# [8 rows x 251 columns]

# %%
sns.scatterplot(twofive_twofour,x = "hit_24", y = "hit_25")
# Out:
# <Axes: xlabel='hit_24', ylabel='hit_25'>

# %%
def correlation(x,y):
    sns.scatterplot(twofive_twofour,x = x, y = y)

correlation("hit_25","hit_24")

# %%
df_24.columns
# Out:
# Index(['last_name, first_name', 'player_id', 'year', 'player_age', 'ab', 'pa',
#        'hit', 'single', 'double', 'triple',
#        ...
#        'linedrives_percent', 'linedrives', 'popups_percent', 'popups',
#        'maxeff_arm_2b_3b_sba', 'n_outs_above_average',
#        'rel_league_reaction_distance', 'rel_league_burst_distance',
#        'rel_league_routing_distance', 'sprint_speed'],
#       dtype='str', length=127)

# %%
pitches_25 = pd.read_csv("~/Desktop/pitches_25.csv")

# %%
twofive_twofour.columns
# Out:
# Index(['last_name, first_name_24', 'player_id', 'year_24', 'player_age_24',
#        'ab_24', 'pa_24', 'hit_24', 'single_24', 'double_24', 'triple_24',
#        ...
#        'linedrives_percent_25', 'linedrives_25', 'popups_percent_25',
#        'popups_25', 'maxeff_arm_2b_3b_sba_25', 'n_outs_above_average_25',
#        'rel_league_reaction_distance_25', 'rel_league_burst_distance_25',
#        'rel_league_routing_distance_25', 'sprint_speed_25'],
#       dtype='str', length=253)

# %%
# Out:
# Stabilized at: 120 PA's
# Stabilized at: 160 PA's
#      pa  correlation
# 0   100     0.632199
# 1   110     0.647057
# 2   120     0.667834
# 3   130     0.684876
# 4   140     0.693329
# 5   150     0.705260
# 6   160     0.723955
# 7   170     0.733613
# 8   180     0.737826
# 9   190     0.746013
# 10  200     0.749683
# 11  210     0.749711
# 12  220     0.752378
# 13  230     0.756462
# 14  240     0.765628
# 15  250     0.771013
# 16  260     0.779417
# 17  270     0.785210
# 18  280     0.786754
# 19  290     0.787280
# 20  300     0.790625
# 21  310     0.796008
# 22  320     0.798297
# 23  330     0.800150
# 24  340     0.798162
# 25  350     0.800915
# 26  360     0.803645
# 27  370     0.804194
# 28  380     0.802441
# 29  390     0.802892
# 30  400     0.804104
# 31  410     0.806652
# 32  420     0.808701
# 33  430     0.809368
# 34  440     0.810930
# 35  450     0.810452
# 36  460     0.811576
# 37  470     0.812888
# 38  480     0.815143
# 39  490     0.817239
# 40  500     0.817788
# 41  510     0.817662
# 42  520     0.817867
# 43  530     0.817499
# 44  540     0.818015
# 45  550     0.818653
# 46  560     0.818914
# 47  570     0.819136
# 48  580     0.819276
# 49  590     0.818642

# %%
# Out:
# 2026-04-30 14:18:20.727 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:18:20.928
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/jacobsilverman/PycharmProjects/beisbol/.venv/lib/python3.14/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-04-30 14:18:20.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:18:20.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Out:
# 2026-04-30 14:20:53.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:20:53.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:20:53.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:20:53.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:20:53.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:20:53.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:20:53.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:20:53.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:20:53.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:20:53.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:20:53.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:20:53.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:20:53.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 14:20:53.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 5
#       1 x_var = st.selectbox("Choose X variable",twofive_twofour.columns)
#       2 y_var = st.selectbox("Choose Y variable",twofive_twofour.columns)
#       3
#       4 if x_var and y_var:
# ----> 5     corr = twofive_twofour[x_var].corr(twofive_twofour[y_var])
#       6     st.write(f"Correlation: {corr}")
#       7
#       8     fig = sns.scatterplot(data = twofive_twofour, x = x_var, y = y_var)
#
# File ~/PycharmProjects/beisbol/.venv/lib/python3.14/site-packages/pandas/core/series.py:2770, in Series.corr(self, other, method, min_periods)
#    2767 if len(this) == 0:
#    2768     return np.nan
# -> 2770 this_values = this.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    2771 other_values = other.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    2773 if method in ["pearson", "spearman", "kendall"] or callable(method):
#
# File ~/PycharmProjects/beisbol/.venv/lib/python3.14/site-packages/pandas/core/base.py:664, in IndexOpsMixin.to_numpy(self, dtype, copy, na_value, **kwargs)
#     574 """
#     575 A NumPy ndarray representing the values in this Series or Index.
#     576
#    (...)    661       dtype='datetime64[ns]')
#     662 """
#     663 if isinstance(self.dtype, ExtensionDtype):
# --> 664     return self.array.to_numpy(dtype, copy=copy, na_value=na_value, **kwargs)
#     665 elif kwargs:
#     666     bad_keys = next(iter(kwargs.keys()))
#
# File ~/PycharmProjects/beisbol/.venv/lib/python3.14/site-packages/pandas/core/arrays/numpy_.py:589, in NumpyExtensionArray.to_numpy(self, dtype, copy, na_value)
#     586         result = result.view()
#     587         result.flags.writeable = False
# --> 589 result = np.asarray(result, dtype=dtype)
#     591 if copy and result is self._ndarray:
#     592     result = result.copy()
#
# ValueError: could not convert string to float: 'Marte, Ketel'

# %%
df_24 = pd.read_csv("~/Desktop/stats-3.csv")
corrs_df_24 = df_24.select_dtypes('number')
corrs_df_24 = corrs_df_24.drop(['b_rbi', 'b_lob', 'b_total_bases', 'r_total_caught_stealing', 'r_total_stolen_base', 'b_ab_scoring', 'b_ball', 'b_called_strike', 'b_catcher_interf', 'b_foul', 'b_foul_tip', 'b_game', 'b_gnd_into_dp', 'b_gnd_into_tp', 'b_gnd_rule_double', 'b_hit_by_pitch', 'b_hit_ground', 'b_hit_fly', 'b_hit_into_play', 'b_hit_line_drive', 'b_hit_popup', 'b_out_fly', 'b_out_ground', 'b_out_line_drive', 'b_out_popup','flareburner_percent', 'poorlyunder_percent', 'poorlytopped_percent', 'poorlyweak_percent','pitch_count_offspeed', 'pitch_count_fastball', 'pitch_count_breaking', 'pitch_count','maxeff_arm_2b_3b_sba', 'n_outs_above_average', 'rel_league_reaction_distance', 'rel_league_burst_distance', 'rel_league_routing_distance',
  'swords','solidcontact_percent','popups','groundballs','flyballs','linedrives','batted_ball',
   'out_zone_swing','vertical_swing_path','out_zone_swing_miss','in_zone','out_zone', 'out_zone_percent','avg_hyper_speed', 'blasts_contact', 'edge','blasts_swing','bacon','xbacon','xbadiff', 'xslgdiff', 'wobadiff','ideal_angle_rate','xobp','xiso']
                               ,axis = 1)

pd.set_option('display.max_columns', None)
print(corrs_df_24.columns.tolist())
# Out:
# ['player_id', 'year', 'player_age', 'ab', 'pa', 'hit', 'single', 'double', 'triple', 'home_run', 'strikeout', 'walk', 'k_percent', 'bb_percent', 'batting_avg', 'slg_percent', 'on_base_percent', 'on_base_plus_slg', 'isolated_power', 'babip', 'xba', 'xslg', 'woba', 'xwoba', 'xobp', 'xiso', 'wobacon', 'xwobacon', 'bacon', 'xbacon', 'xbadiff', 'xslgdiff', 'wobadiff', 'avg_swing_speed', 'fast_swing_rate', 'blasts_contact', 'blasts_swing', 'squared_up_contact', 'squared_up_swing', 'avg_swing_length', 'swords', 'attack_angle', 'attack_direction', 'ideal_angle_rate', 'vertical_swing_path', 'exit_velocity_avg', 'launch_angle_avg', 'sweet_spot_percent', 'barrel', 'barrel_batted_rate', 'solidcontact_percent', 'hard_hit_percent', 'avg_best_speed', 'avg_hyper_speed', 'z_swing_percent', 'z_swing_miss_percent', 'oz_swing_percent', 'oz_swing_miss_percent', 'oz_contact_percent', 'out_zone_swing_miss', 'out_zone_swing', 'out_zone_percent', 'out_zone', 'meatball_swing_percent', 'meatball_percent', 'iz_contact_percent', 'in_zone_swing_miss', 'in_zone_swing', 'in_zone_percent', 'in_zone', 'edge_percent', 'edge', 'whiff_percent', 'swing_percent', 'pull_percent', 'straightaway_percent', 'opposite_percent', 'batted_ball', 'f_strike_percent', 'groundballs_percent', 'groundballs', 'flyballs_percent', 'flyballs', 'linedrives_percent', 'linedrives', 'popups_percent', 'popups', 'sprint_speed']

# %%
#rename A to alpha, new name is second
#corrs_df = corrs_df.rename(columns = {"A":"Alpha"})

# %%
df_25 = pd.read_csv("~/Desktop/stats-3.csv")
corrs_df_25 = df_25.select_dtypes('number')
corrs_df_25 = corrs_df_25.drop(['b_rbi', 'b_lob', 'b_total_bases', 'r_total_caught_stealing', 'r_total_stolen_base', 'b_ab_scoring', 'b_ball', 'b_called_strike', 'b_catcher_interf', 'b_foul', 'b_foul_tip', 'b_game', 'b_gnd_into_dp', 'b_gnd_into_tp', 'b_gnd_rule_double', 'b_hit_by_pitch', 'b_hit_ground', 'b_hit_fly', 'b_hit_into_play', 'b_hit_line_drive', 'b_hit_popup', 'b_out_fly', 'b_out_ground', 'b_out_line_drive', 'b_out_popup','flareburner_percent', 'poorlyunder_percent', 'poorlytopped_percent', 'poorlyweak_percent','pitch_count_offspeed', 'pitch_count_fastball', 'pitch_count_breaking', 'pitch_count','maxeff_arm_2b_3b_sba', 'n_outs_above_average', 'rel_league_reaction_distance', 'rel_league_burst_distance', 'rel_league_routing_distance',
  'swords','solidcontact_percent','popups','groundballs','flyballs','linedrives','batted_ball',
   'out_zone_swing','vertical_swing_path','out_zone_swing_miss','in_zone','out_zone', 'out_zone_percent','avg_hyper_speed', 'blasts_contact', 'edge','blasts_swing','bacon','xbacon','xbadiff', 'xslgdiff', 'wobadiff','ideal_angle_rate','xobp','xiso']
                               ,axis = 1)

corrs_df_25.columns = [column.replace("percent","%").replace("_"," ").replace("z","zone").replace("avg","Average").replace("slg","Slugging").title()
                       for column in corrs_df_25.columns]
pd.set_option('display.max_columns', None)
print(corrs_df_25.columns.tolist())
# Out:
# ['Player Id', 'Year', 'Player Age', 'Ab', 'Pa', 'Hit', 'Single', 'Double', 'Triple', 'Home Run', 'Strikeout', 'Walk', 'K %', 'Bb %', 'Batting Average', 'Slugging %', 'On Base %', 'On Base Plus Slugging', 'Isolated Power', 'Babip', 'Xba', 'Xslugging', 'Woba', 'Xwoba', 'Wobacon', 'Xwobacon', 'Average Swing Speed', 'Fast Swing Rate', 'Squared Up Contact', 'Squared Up Swing', 'Average Swing Length', 'Attack Angle', 'Attack Direction', 'Exit Velocity Average', 'Launch Angle Average', 'Sweet Spot %', 'Barrel', 'Barrel Batted Rate', 'Hard Hit %', 'Average Best Speed', 'Zone Swing %', 'Zone Swing Miss %', 'Ozone Swing %', 'Ozone Swing Miss %', 'Ozone Contact %', 'Meatball Swing %', 'Meatball %', 'Izone Contact %', 'In Zoneone Swing Miss', 'In Zoneone Swing', 'In Zoneone %', 'Edge %', 'Whiff %', 'Swing %', 'Pull %', 'Straightaway %', 'Opposite %', 'F Strike %', 'Groundballs %', 'Flyballs %', 'Linedrives %', 'Popups %', 'Sprint Speed']

# %%
corrs_df_24 = df_24.select_dtypes('number')
print('player_id' in corrs_df_24.columns)
# Out:
# True

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import streamlit as st
#read dataframes
df_25 = pd.read_csv("~/Desktop/stats-2.csv")
df_24 = pd.read_csv("~/Desktop/stats-3.csv")

pitches_25 = pd.read_csv("~/Desktop/pitches_25.csv")

corrs_df_24 = df_24.select_dtypes('number')

corrs_df_24 = corrs_df_24.drop(['b_rbi', 'b_lob', 'b_total_bases', 'r_total_caught_stealing', 'r_total_stolen_base', 'b_ab_scoring', 'b_ball', 'b_called_strike', 'b_catcher_interf', 'b_foul', 'b_foul_tip', 'b_game', 'b_gnd_into_dp', 'b_gnd_into_tp', 'b_gnd_rule_double', 'b_hit_by_pitch', 'b_hit_ground', 'b_hit_fly', 'b_hit_into_play', 'b_hit_line_drive', 'b_hit_popup', 'b_out_fly', 'b_out_ground', 'b_out_line_drive', 'b_out_popup','flareburner_percent', 'poorlyunder_percent', 'poorlytopped_percent', 'poorlyweak_percent','pitch_count_offspeed', 'pitch_count_fastball', 'pitch_count_breaking', 'pitch_count','maxeff_arm_2b_3b_sba', 'n_outs_above_average', 'rel_league_reaction_distance', 'rel_league_burst_distance', 'rel_league_routing_distance',
  'swords','solidcontact_percent','popups','groundballs','flyballs','linedrives','batted_ball',
   'out_zone_swing','vertical_swing_path','out_zone_swing_miss','in_zone','out_zone', 'out_zone_percent','avg_hyper_speed', 'blasts_contact', 'edge','blasts_swing','bacon','xbacon','xbadiff', 'xslgdiff', 'wobadiff','ideal_angle_rate','xobp','xiso']
                               ,axis = 1)

pd.set_option('display.max_columns', None)
print(corrs_df_24.columns.tolist())

corrs_df_25 = df_25.select_dtypes('number')
corrs_df_25 = corrs_df_25.drop(['b_rbi', 'b_lob', 'b_total_bases', 'r_total_caught_stealing', 'r_total_stolen_base', 'b_ab_scoring', 'b_ball', 'b_called_strike', 'b_catcher_interf', 'b_foul', 'b_foul_tip', 'b_game', 'b_gnd_into_dp', 'b_gnd_into_tp', 'b_gnd_rule_double', 'b_hit_by_pitch', 'b_hit_ground', 'b_hit_fly', 'b_hit_into_play', 'b_hit_line_drive', 'b_hit_popup', 'b_out_fly', 'b_out_ground', 'b_out_line_drive', 'b_out_popup','flareburner_percent', 'poorlyunder_percent', 'poorlytopped_percent', 'poorlyweak_percent','pitch_count_offspeed', 'pitch_count_fastball', 'pitch_count_breaking', 'pitch_count','maxeff_arm_2b_3b_sba', 'n_outs_above_average', 'rel_league_reaction_distance', 'rel_league_burst_distance', 'rel_league_routing_distance',
  'swords','solidcontact_percent','popups','groundballs','flyballs','linedrives','batted_ball',
   'out_zone_swing','vertical_swing_path','out_zone_swing_miss','in_zone','out_zone', 'out_zone_percent','avg_hyper_speed', 'blasts_contact', 'edge','blasts_swing','bacon','xbacon','xbadiff', 'xslgdiff', 'wobadiff','ideal_angle_rate','xobp','xiso']
                               ,axis = 1)

corrs_df_25.columns = [column.replace("percent","%").replace("_"," ").replace("z","zone").replace("avg","Average").replace("slg","Slugging").title()
                       for column in corrs_df_25.columns]
pd.set_option('display.max_columns', None)
print(corrs_df_24.columns.tolist())



st.title("Correlation Explorer")
x_year = st.radio("Select Year for X variable", [2024, 2025])
y_year = st.radio("Select Year for Y variable", [2024, 2025])
if x_year == 2024:
    x_var = st.selectbox("Choose X variable",corrs_df_24.columns)
    x_df = corrs_df_24
else:
    x_var = st.selectbox("Choose X variable", corrs_df_25.columns)
    x_df = corrs_df_25
if y_year == 2024:
    y_var = st.selectbox("Choose Y variable",corrs_df_24.columns)
    y_df = corrs_df_24
else:
    y_var = st.selectbox("Choose Y variable", corrs_df_25.columns)
    y_df = corrs_df_25

if x_var and y_var:

    corr = (x_df[x_var]).corr(y_df[y_var])
    st.write(f"Correlation: {corr}")
    #rename the columns and create a df with player id and the column
    x_col = x_df[['player_id', x_var]].rename(columns={x_var: 'x_val'})
    y_col = y_df[['player_id', y_var]].rename(columns={y_var: 'y_val'})
    #merge these two on player id

print(x_col.columns.tolist())
print(y_col.columns.tolist())
# Out:
# 2026-04-30 20:42:59.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 20:42:59.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ['player_id', 'year', 'player_age', 'ab', 'pa', 'hit', 'single', 'double', 'triple', 'home_run', 'strikeout', 'walk', 'k_percent', 'bb_percent', 'batting_avg', 'slg_percent', 'on_base_percent', 'on_base_plus_slg', 'isolated_power', 'babip', 'xba', 'xslg', 'woba', 'xwoba', 'wobacon', 'xwobacon', 'avg_swing_speed', 'fast_swing_rate', 'squared_up_contact', 'squared_up_swing', 'avg_swing_length', 'attack_angle', 'attack_direction', 'exit_velocity_avg', 'launch_angle_avg', 'sweet_spot_percent', 'barrel', 'barrel_batted_rate', 'hard_hit_percent', 'avg_best_speed', 'z_swing_percent', 'z_swing_miss_percent', 'oz_swing_percent', 'oz_swing_miss_percent', 'oz_contact_percent', 'meatball_swing_percent', 'meatball_percent', 'iz_contact_percent', 'in_zone_swing_miss', 'in_zone_swing', 'in_zone_percent', 'edge_percent', 'whiff_percent', 'swing_percent', 'pull_percent', 'straightaway_percent', 'opposite_percent', 'f_strike_percent', 'groundballs_percent', 'flyballs_percent', 'linedrives_percent', 'popups_percent', 'sprint_speed']
# ['player_id', 'year', 'player_age', 'ab', 'pa', 'hit', 'single', 'double', 'triple', 'home_run', 'strikeout', 'walk', 'k_percent', 'bb_percent', 'batting_avg', 'slg_percent', 'on_base_percent', 'on_base_plus_slg', 'isolated_power', 'babip', 'xba', 'xslg', 'woba', 'xwoba', 'wobacon', 'xwobacon', 'avg_swing_speed', 'fast_swing_rate', 'squared_up_contact', 'squared_up_swing', 'avg_swing_length', 'attack_angle', 'attack_direction', 'exit_velocity_avg', 'launch_angle_avg', 'sweet_spot_percent', 'barrel', 'barrel_batted_rate', 'hard_hit_percent', 'avg_best_speed', 'z_swing_percent', 'z_swing_miss_percent', 'oz_swing_percent', 'oz_swing_miss_percent', 'oz_contact_percent', 'meatball_swing_percent', 'meatball_percent', 'iz_contact_percent', 'in_zone_swing_miss', 'in_zone_swing', 'in_zone_percent', 'edge_percent', 'whiff_percent', 'swing_percent', 'pull_percent', 'straightaway_percent', 'opposite_percent', 'f_strike_percent', 'groundballs_percent', 'flyballs_percent', 'linedrives_percent', 'popups_percent', 'sprint_speed']
# ['x_val', 'x_val']
# ['y_val', 'y_val']

# %%
df_24.columns
pd.set_option('display.max_columns', None)
print(corrs_df_24.columns.tolist())
# Out:
# ['player_id', 'year', 'player_age', 'ab', 'pa', 'hit', 'single', 'double', 'triple', 'home_run', 'strikeout', 'walk', 'k_percent', 'bb_percent', 'batting_avg', 'slg_percent', 'on_base_percent', 'on_base_plus_slg', 'isolated_power', 'babip', 'xba', 'xslg', 'woba', 'xwoba', 'wobacon', 'xwobacon', 'avg_swing_speed', 'fast_swing_rate', 'squared_up_contact', 'squared_up_swing', 'avg_swing_length', 'attack_angle', 'attack_direction', 'exit_velocity_avg', 'launch_angle_avg', 'sweet_spot_percent', 'barrel', 'barrel_batted_rate', 'hard_hit_percent', 'avg_best_speed', 'z_swing_percent', 'z_swing_miss_percent', 'oz_swing_percent', 'oz_swing_miss_percent', 'oz_contact_percent', 'meatball_swing_percent', 'meatball_percent', 'iz_contact_percent', 'in_zone_swing_miss', 'in_zone_swing', 'in_zone_percent', 'edge_percent', 'whiff_percent', 'swing_percent', 'pull_percent', 'straightaway_percent', 'opposite_percent', 'f_strike_percent', 'groundballs_percent', 'flyballs_percent', 'linedrives_percent', 'popups_percent', 'sprint_speed']

# %%
print(pitches_25.columns.tolist())
# Out:
# ['pitch_type', 'game_date', 'release_speed', 'release_pos_x', 'release_pos_z', 'player_name', 'batter', 'pitcher', 'events', 'description', 'spin_dir', 'spin_rate_deprecated', 'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des', 'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type', 'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x', 'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y', 'tfs_deprecated', 'tfs_zulu_deprecated', 'umpire', 'sv_id', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot', 'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed', 'release_spin_rate', 'release_extension', 'game_pk', 'fielder_2', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8', 'fielder_9', 'release_pos_y', 'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle', 'woba_value', 'woba_denom', 'babip_value', 'iso_value', 'launch_speed_angle', 'at_bat_number', 'pitch_number', 'pitch_name', 'home_score', 'away_score', 'bat_score', 'fld_score', 'post_away_score', 'post_home_score', 'post_bat_score', 'post_fld_score', 'if_fielding_alignment', 'of_fielding_alignment', 'spin_axis', 'delta_home_win_exp', 'delta_run_exp', 'bat_speed', 'swing_length', 'estimated_slg_using_speedangle', 'delta_pitcher_run_exp', 'hyper_speed', 'home_score_diff', 'bat_score_diff', 'home_win_exp', 'bat_win_exp', 'age_pit_legacy', 'age_bat_legacy', 'age_pit', 'age_bat', 'n_thruorder_pitcher', 'n_priorpa_thisgame_player_at_bat', 'pitcher_days_since_prev_game', 'batter_days_since_prev_game', 'pitcher_days_until_next_game', 'batter_days_until_next_game', 'api_break_z_with_gravity', 'api_break_x_arm', 'api_break_x_batter_in', 'arm_angle', 'attack_angle', 'attack_direction', 'swing_path_tilt', 'intercept_ball_minus_batter_pos_x_inches', 'intercept_ball_minus_batter_pos_y_inches']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import streamlit as st
#read dataframes
df_25 = pd.read_csv("~/Desktop/stats-2.csv")
df_24 = pd.read_csv("~/Desktop/stats-3.csv")

pitches_25 = pd.read_csv("~/Desktop/pitches_25.csv")

corrs_df_24 = df_24.select_dtypes('number')

corrs_df_24 = corrs_df_24.drop(['b_rbi', 'b_lob', 'player_age','b_total_bases', 'r_total_caught_stealing', 'r_total_stolen_base', 'b_ab_scoring', 'b_ball', 'b_called_strike', 'b_catcher_interf', 'b_foul', 'b_foul_tip', 'b_game', 'b_gnd_into_dp', 'b_gnd_into_tp', 'b_gnd_rule_double', 'b_hit_by_pitch', 'b_hit_ground', 'b_hit_fly', 'b_hit_into_play', 'b_hit_line_drive', 'b_hit_popup', 'b_out_fly', 'b_out_ground', 'b_out_line_drive', 'b_out_popup','flareburner_percent', 'poorlyunder_percent', 'poorlytopped_percent', 'poorlyweak_percent','pitch_count_offspeed', 'pitch_count_fastball', 'pitch_count_breaking', 'pitch_count','maxeff_arm_2b_3b_sba', 'n_outs_above_average', 'rel_league_reaction_distance', 'rel_league_burst_distance', 'rel_league_routing_distance',
  'swords','solidcontact_percent','popups','groundballs','flyballs','linedrives','batted_ball',
   'out_zone_swing','f_strike_percent','vertical_swing_path','out_zone_swing_miss','in_zone','out_zone', 'out_zone_percent','avg_hyper_speed', 'year','blasts_contact', 'edge','blasts_swing','bacon','xbacon','xbadiff', 'xslgdiff', 'wobadiff','ideal_angle_rate','xobp','xiso']
                               ,axis = 1)

pd.set_option('display.max_columns', None)
print(corrs_df_24.columns.tolist())

corrs_df_25 = df_25.select_dtypes('number')
corrs_df_25 = corrs_df_25.drop(['b_rbi', 'player_age','b_lob', 'b_total_bases', 'r_total_caught_stealing', 'r_total_stolen_base', 'b_ab_scoring', 'b_ball', 'b_called_strike', 'b_catcher_interf', 'b_foul', 'b_foul_tip', 'b_game', 'b_gnd_into_dp', 'b_gnd_into_tp', 'b_gnd_rule_double', 'b_hit_by_pitch', 'b_hit_ground', 'b_hit_fly', 'b_hit_into_play', 'b_hit_line_drive', 'b_hit_popup', 'b_out_fly', 'b_out_ground', 'b_out_line_drive', 'b_out_popup','flareburner_percent', 'poorlyunder_percent', 'poorlytopped_percent', 'poorlyweak_percent','pitch_count_offspeed', 'pitch_count_fastball', 'pitch_count_breaking', 'pitch_count','maxeff_arm_2b_3b_sba', 'n_outs_above_average', 'rel_league_reaction_distance', 'rel_league_burst_distance', 'rel_league_routing_distance',
  'swords','solidcontact_percent','popups','groundballs','flyballs','linedrives','batted_ball',
   'out_zone_swing','f_strike_percent','vertical_swing_path','year','out_zone_swing_miss','in_zone','out_zone', 'out_zone_percent','avg_hyper_speed', 'blasts_contact', 'edge','blasts_swing','bacon','xbacon','xbadiff', 'xslgdiff', 'wobadiff','ideal_angle_rate','xobp','xiso']
                               ,axis = 1)
# rename columns but keep player_id as is
corrs_df_24.columns = [c if c == 'player_id' else c.replace("percent","%").replace("_"," ").replace("z","zone").replace("avg","Average").replace("slg","Slugging").replace("opposite","Oppo").title() for c in corrs_df_24.columns]
corrs_df_25.columns = [c if c == 'player_id' else c.replace("percent","%").replace("_"," ").replace("z","zone").replace("avg","Average").replace("slg","Slugging").replace("opposite","Oppo").title() for c in corrs_df_25.columns]

# stat columns only (no player_id)
stat_cols_24 = [c for c in corrs_df_24.columns if c != 'player_id']
stat_cols_25 = [c for c in corrs_df_25.columns if c != 'player_id']

st.title("Correlation Explorer")
x_year = st.radio("Select Year for X variable", [2024, 2025])
y_year = st.radio("Select Year for Y variable", [2024, 2025])
if x_year == 2024:
    x_var = st.selectbox("Choose X variable",corrs_df_24.columns)
    x_df = corrs_df_24
else:
    x_var = st.selectbox("Choose X variable", corrs_df_25.columns)
    x_df = corrs_df_25
if y_year == 2024:
    y_var = st.selectbox("Choose Y variable",corrs_df_24.columns)
    y_df = corrs_df_24
else:
    y_var = st.selectbox("Choose Y variable", corrs_df_25.columns)
    y_df = corrs_df_25

if x_var and y_var:

    corr = (x_df[x_var]).corr(y_df[y_var])
    st.write(f"Correlation: {corr}")
    #rename the columns and create a df with player id and the column
    x_col = x_df[x_var].rename('x_val')
    x_col = pd.concat([df_24['player_id'] if x_year == 2024 else df_25['player_id'], x_col], axis=1)

    y_col = y_df[y_var].rename('y_val')
    y_col = pd.concat([df_24['player_id'] if y_year == 2024 else df_25['player_id'], y_col], axis=1)


    #merge these two on player id
    graph_df = pd.merge(x_col, y_col, on='player_id', how='inner')

    fig, ax = plt.subplots()
    ax.set_xlabel(x_var)
    ax.set_ylabel(y_var)
    sns.scatterplot(data=graph_df, x='x_val', y='y_val', ax=ax)
    st.pyplot(fig)

print(graph_df.head(10))
print(len(graph_df))
# Out:
# 2026-04-30 21:33:10.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.831 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.831 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:10.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ['player_id', 'ab', 'pa', 'hit', 'single', 'double', 'triple', 'home_run', 'strikeout', 'walk', 'k_percent', 'bb_percent', 'batting_avg', 'slg_percent', 'on_base_percent', 'on_base_plus_slg', 'isolated_power', 'babip', 'xba', 'xslg', 'woba', 'xwoba', 'wobacon', 'xwobacon', 'avg_swing_speed', 'fast_swing_rate', 'squared_up_contact', 'squared_up_swing', 'avg_swing_length', 'attack_angle', 'attack_direction', 'exit_velocity_avg', 'launch_angle_avg', 'sweet_spot_percent', 'barrel', 'barrel_batted_rate', 'hard_hit_percent', 'avg_best_speed', 'z_swing_percent', 'z_swing_miss_percent', 'oz_swing_percent', 'oz_swing_miss_percent', 'oz_contact_percent', 'meatball_swing_percent', 'meatball_percent', 'iz_contact_percent', 'in_zone_swing_miss', 'in_zone_swing', 'in_zone_percent', 'edge_percent', 'whiff_percent', 'swing_percent', 'pull_percent', 'straightaway_percent', 'opposite_percent', 'groundballs_percent', 'flyballs_percent', 'linedrives_percent', 'popups_percent', 'sprint_speed']
# 2026-04-30 21:33:11.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:11.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:33:11.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#    player_id   x_val   y_val
# 0     606466  606466  606466
# 1     542303  542303  542303
# 2     641857  641857  641857
# 3     596019  596019  596019
# 4     678662  678662  678662
# 5     671218  671218  671218
# 6     670541  670541  670541
# 7     607208  607208  607208
# 8     547180  547180  547180
# 9     694192  694192  694192
# 129

# %%
print(stat_cols_24[:5])
# Out:
# ['Ab', 'Pa', 'Hit', 'Single', 'Double']
